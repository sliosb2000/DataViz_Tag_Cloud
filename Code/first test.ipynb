# %% [markdown]
# # FROM https://www.geeksforgeeks.org/generating-word-cloud-python/

# %%
# Python program to generate WordCloud

# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Reads 'Youtube04-Eminem.csv' file
df = pd.read_csv(r"Youtube04-Eminem.csv", encoding ="latin-1")

comment_words = ''
stopwords = set(STOPWORDS)

# iterate through the csv file
for val in df.CONTENT:
	
	# typecaste each val to string
	val = str(val)

	# split the value
	tokens = val.split()
	
	# Converts each token into lowercase
	for i in range(len(tokens)):
		tokens[i] = tokens[i].lower()
	
	comment_words += " ".join(tokens)+" "
	#print(len(comment_words)," ",comment_words[0],"\n")
    
wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plot the WordCloud image					
fig, ax = plt.subplots()
#plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'C:/Users/HP/OneDrive - De Vinci/1CSULB/Data Visualization/DataViz_Tag_Cloud/Code/myimage.svg'

fig.savefig(image_name, format=image_format, dpi=1200)

plt.show()

# %%
text = "Contrary to popular belief, Lorem Ipsum is not simply random text. It has roots in a piece of classical Latin literature from 45 BC, making it over 2000 years old. Richard McClintock, a Latin professor at Hampden-Sydney College in Virginia, looked up one of the more obscure Latin words, consectetur, from a Lorem Ipsum passage, and going through the cites of the word in classical literature, discovered the undoubtable source. Lorem Ipsum comes from sections 1.10.32 and 1.10.33 of de Finibus Bonorum et Malorum (The Extremes of Good and Evil) by Cicero, written in 45 BC. This book is a treatise on the theory of ethics, very popular during the Renaissance. The first line of Lorem Ipsum, Lorem ipsum dolor sit amet.., comes from a line in section 1.10.32. The standard chunk of Lorem Ipsum used since the 1500s is reproduced below for those interested. Sections 1.10.32 and 1.10.33 from de Finibus Bonorum et Malorum by Cicero are also reproduced in their exact original form, accompanied by English versions from the 1914 translation by H. Rackham."

# %%
   
wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(text)

# plot the WordCloud image					
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
print(stopwords)
# Out:
# {'our', "hadn't", 'after', 'own', 'theirs', 'themselves', 'too', "what's", "that's", "she'll", 'on', "hasn't", 'since', 'yourself', "wasn't", 'yourselves', "there's", 'when', 'com', "they've", 'off', 'out', "when's", 'as', 'over', 'above', 'been', 'has', "isn't", "doesn't", 'through', 'in', 'did', 'during', 'hence', 'else', "i'd", 'just', 'ours', 'the', 'get', 'of', 'myself', 'they', "didn't", "i've", 'nor', 'to', "i'll", 'do', 'it', 'r', 'my', 'most', 'under', 'we', 'and', "they're", 'are', "shan't", 'than', 'ought', 'up', 'can', 'against', 'their', 'also', 'his', 'into', 'until', "why's", 'where', 'could', "we're", 'how', 'only', 'both', 'www', 'all', 'same', 'for', 'each', 'your', 'should', 'such', "shouldn't", 'there', "they'd", 'very', "we'd", 'down', 'few', "wouldn't", 'however', 'being', 'at', "weren't", 'by', "here's", "it's", 'she', 'which', "can't", 'here', "he'd", 'so', 'while', "we've", "couldn't", 'these', 'k', 'ever', 'other', 'does', 'himself', 'therefore', "you've", 'again', 'about', 'have', "i'm", "haven't", 'with', "aren't", 'itself', 'some', 'because', 'like', 'cannot', "he'll", 'once', "she's", 'yours', "you'd", 'not', 'is', 'would', "where's", 'a', 'its', 'that', 'them', 'i', 'hers', 'am', 'me', 'whom', 'you', "we'll", 'any', 'below', 'who', "you're", "let's", 'shall', 'between', 'having', 'why', 'further', 'otherwise', "she'd", 'had', "you'll", 'doing', 'her', 'an', "don't", 'what', 'if', 'before', 'he', 'be', "they'll", 'those', 'or', 'no', "mustn't", 'herself', "how's", 'this', "won't", 'more', 'were', 'ourselves', 'was', 'then', "he's", "who's", 'him', 'http', 'from', 'but'}

# %% [markdown]
# # https://matplotlib.org/stable/users/explain/interactive.html

# %%
# %matplotlib
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: Qt5Agg

# %%
fig, ax = plt.subplots()

# %%
ln, = ax.plot(range(5))

# %%
ln.set_color('orange')

# %%
plt.ion()

# %% [markdown]
# # https://www.datacamp.com/tutorial/wordcloud-python

# %%
# Menu deroulant interactife tag  cloud https://www.youtube.com/watch?v=J3kpHpjtKDg

# %%
# fully interactive ??
#https://medium.com/@thalia181189/want-to-create-fully-interactive-plots-with-python-d54ab28760d9
